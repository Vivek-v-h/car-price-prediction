# %%
cars={
    "swift":9,
    "alto":5.5,
    "dzire":9.5,
    "ciaz":12.5,
    "brezza":10,
    "baleno":9,
    "ertiga":11,
    "wagonr":6,
    "xl6":11,
    "celerio":5.4,
    "jimny":13,
    "Spresso":4.5,
    "Ignis":6.44,
    "Kizashi":17,
    "virtus":19,
    "taigun":13,
    "tigwan":40,
    "polo":10,
    "vento":11,
    "jetta":20,
    "passat":30,
    "slavia":14,
    "kushaq":20,
    "kodiaq":43,
    "superb":25,
    "octavia":30,
    "rapid":8,
    "fabia":7.5,
    "etios":7,
    "etios liva":5,
    "innova":11,
    "fortutner":24,
    "glanza":9,
    "innova crysta":16,
    "land cruiser":100,
    "velfire":99,
    "yaris":9,
    "corolla altis":14,
    "hilux":45,
    "camry":51,
    "hector":18,
    "astor":14,
    "kwid":5,
    "triber":7,
    "kiger":7.4,
    "duster":14,
    "lodgy":11,
    "fluence":12,
    "logan":7,
    "pulse":7,
    "scala":12,
    "captur":11,
    "nexon":12,
    "punch":10,
    "altroz":10.7,
    "Harrier":23,
    "tiago":8,
    "safari":21,
    "tigor":8,
    "indica":5,
    "estate":2.5,
    "manza":9,
    "nano":3,
    "sumo":10,
    "yodha":6,
    "creta":11,
    "venue":9,
    "i20":9,
    "verna":16,
    "santro":6.45,
    "alcazar":20,
    "tucson":30,
    "Aura":8,
    "Accent":7,
    "Eon":4,
    "Getz":4.5,
    "Santafe":30,
    "i10":6,
    "Terracan":22,
    "Elantra":17,
    "City":15,
    "WR-V":10.8,
    "Jazz":9.95,
    "Amaze":7.5,
    "Accord":43.2,
    "Brio":5,
    "CR-V":30,
    "Civic":23,
    "Mobilio":12.5,
    "BR-V":13.5,
    "Scorpio":14,
    "XUV 300":10,
    "Bolero":10,
    "Scorpio N":12,
    "Bolero Neo":9,
    "XUV 700":23,
    "XUV 500":13,
    "Marazzo":15,
    "Alturas G4":32,
    "Thar":12,
    "KUV 100":7,
    "Zylo":12,
    "Verito":8.5,
    "Voyager":6,
    "Verito vive":6.5,
    "TUV 300":10,
    "Compass":25,
    "Wrangler":64,
    "Merdian":30,
    "Grand cherokee":78,
    "Carens":11,
    "Seltos":13,
    "Sonet":9,
    "Carnival":35,
    "Amg g63":400,
    "Amg gle":207,
    "Amg gt":240,
    "Amg glc":150,
    "Amg gla":100,
    "Amg e63":177,
    "Amg c43":108,
    "Amg slc":235,
    "Amg clk55":85,
    "G class":255,
    "E class":88,
    "A class":46,
    "GlLE class":97,
    "GLS class":125,
    "GLC class":66,
    "V class":150,
    "Maybach S-Class":330,
    "Maybach GLS":250,
    "Xc90":100,
    "Xc40":43,
    "Xc60":67,
    "S90":67,
    "S60":46,
    "X7":125,
    "X1":51,
    "3 Series":70,
    "X5":110,
    "M5 CS":200,
    "Z4":90,
    "M4 CS":160,
    "7 Series":200,
    "X6":110,
    "XM":260,
    "5 series":75,
    "X3":87,
    "8 Series":170,
    "M2 CS":110,
    "2 Series":35,
    "6 Series":75,
    "X4":100,
    "X5 M":210,
    "Magnite":11,
    "GTR":212,
    "X Drive":27,
    "Teana":26,
    "Sunny":12,
    "Micra":8,
    "370Z":56,
    "Evalia":15,
    "Terrano":15,
    "Kickz":12,
    "Defender 10":91,
    "Defender 110":230,
    "Range Rover sport":184,
    "Range Rover Valar":95,
    "Range Rover Evoque":73,
    "Discovery Sport":72,
    "Discovery":130,
    "Freelander":45,
    "EcoSport":9,
    "Endavor":35,
    "Figo":6,
    "Aspire":7,
    "Freestyle":6.5,
    "Fiesta":10,
    "Mustang":90,
    "Ikon":5.5,
    "Aveeo":8,
    "Aveeo U-VA":5,
    "Veet":6.5,
    "Captiva":28,
    "Corvette":60,
    "Cruze":18,
    "Enjoy":9.18,
    "Sail":10,
    "Sail Hatchback":8,
    "Forester":10,
    "Optra":12,
    "Spark":4.5,
    "Tavera":11,
    "Trainblaizer":30,
    "Linea":7.5,
    "Plunto":8,
    "Abarat Plunto":12,
    "Avventura":8,
    "Palio":4,
    "Urbancross":7.9,
    "Abarat 595":35,
    "Uno":2.70,
    "Tetra":6,
    "Q3":50,
    "A4":50,
    "A6":72,
    "S5":87.62,
    "Q8":125 ,
    "RS5":130,
    "RS Q8":256,
    "A8":155,
    "Q5":73,
    "Q7":100,
    "911":215,
    "Cayanne":167,
    "Macan":100,
    "Panamera":200,
    "Tycan":270,
    "Hurcan":400,
    "Urus":500,
    "Aventador":512,
    "Revuelto":800,
    "ES":73,
    "LX":330,
    "NX":80,
    "LC":280,
    "RX":110,
    "LX":225,
    "Mini Cooper S":50,
    "Mini Cooper Countryman":55,
    "Gurkha":18,
    "Force 1":15
    
}
# Out:
#   Cell In[3], line 42
#     "hector":18
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pickle;

# %%
pickle.dump(cars,open('cardict.pkl','wb'))
